# %% [markdown]
# # TD 8

# %% [markdown]
# ## Prostate segmentation
# The goal of this TD is to familiarize yourself with medical images, and typical medical tasks.

# %% [markdown]
# After the CT scan of a patient, doctors usually need the contouring of organs (i.e. th set of voxels that correspond to each organ).
#
# Here is an example of a contouring on some sample slices:

# %% [markdown]
# <svg
#    width="45em"
#    height="15em"
#    viewBox="0 0 486.10442 98.305979"
#    version="1.1"
#    id="svg5"
#    xml:space="preserve"
#    inkscape:version="1.2.1 (9c6d41e410, 2022-07-14)"
#    sodipodi:docname="segmentation_bis.svg"
#    xmlns:inkscape="http://www.inkscape.org/namespaces/inkscape"
#    xmlns:sodipodi="http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd"
#    xmlns:xlink="http://www.w3.org/1999/xlink"
#    xmlns="http://www.w3.org/2000/svg"
#    xmlns:svg="http://www.w3.org/2000/svg"><sodipodi:namedview
#      id="namedview7"
#      pagecolor="#ffffff"
#      bordercolor="#000000"
#      borderopacity="0.25"
#      inkscape:showpageshadow="2"
#      inkscape:pageopacity="0.0"
#      inkscape:pagecheckerboard="0"
#      inkscape:deskcolor="#d1d1d1"
#      inkscape:document-units="mm"
#      showgrid="false"
#      inkscape:zoom="0.3581229"
#      inkscape:cx="903.32118"
#      inkscape:cy="37.696556"
#      inkscape:window-width="1920"
#      inkscape:window-height="991"
#      inkscape:window-x="4791"
#      inkscape:window-y="-9"
#      inkscape:window-maximized="1"
#      inkscape:current-layer="layer1" /><defs
#      id="defs2"><pattern
#        patternUnits="userSpaceOnUse"
#        width="256"
#        height="256"
#        id="sand_bitmap"
#        inkscape:stockid="Sand (bitmap)"><!-- Seamless texture provided by FreeSeamlessTextures.com --><!-- License: creative commons attribution --><image
#          width="260"
#          height="260"
#          id="image9"
#          x="0"
#          y="0"
#          xlink:href="..." /></pattern></defs><g
#      inkscape:label="Layer 1"
#      inkscape:groupmode="layer"
#      id="layer1"><g
#        id="g515"
#        transform="translate(4.3497865,-24.380594)"><image
#          width="83.263779"
#          height="62.447838"
#          preserveAspectRatio="none"
#          xlink:href="..."
#          id="image8231"
#          x="129.15219"
#          y="281.42807"
#          transform="matrix(0.85518412,-0.51832433,0.85518412,0.51832433,0,0)" /><image
#          width="83.263779"
#          height="62.447838"
#          preserveAspectRatio="none"
#          xlink:href="..."
#          id="image8243"
#          x="88.289787"
#          y="240.56566"
#          transform="matrix(0.85518412,-0.51832433,0.85518412,0.51832433,0,0)" /><image
#          width="83.263779"
#          height="62.447838"
#          preserveAspectRatio="none"
#          xlink:href="..."
#          id="image8255"
#          x="47.427372"
#          y="199.70325"
#          transform="matrix(0.85518412,-0.51832433,0.85518412,0.51832433,0,0)" /><image
#          width="83.263779"
#          height="62.447838"
#          preserveAspectRatio="none"
#          xlink:href="..."
#          id="image8267"
#          x="6.5649686"
#          y="158.84084"
#          transform="matrix(0.85518412,-0.51832433,0.85518412,0.51832433,0,0)" /><image
#          width="83.263779"
#          height="62.447838"
#          preserveAspectRatio="none"
#          xlink:href="..."
#          id="image8279"
#          x="-34.29744"
#          y="117.97842"
#          transform="matrix(0.85518412,-0.51832433,0.85518412,0.51832433,0,0)" /><image
#          width="83.263779"
#          height="62.447838"
#          preserveAspectRatio="none"
#          xlink:href="..."
#          id="image8291"
#          x="-75.159851"
#          y="77.116013"
#          transform="matrix(0.85518412,-0.51832433,0.85518412,0.51832433,0,0)" /></g></g></svg>

# %% [markdown]
# Doctors used to segment manually each slice, but it is a very tedious task. So, they are now using models to do this automatically; and they only need to check the results.
#
# In this TD, we will use a dataset of prostate 3D images, and we will segment the prostate gland.

# %% [markdown]
# ---

# %%
# usual imports
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
torch.manual_seed(0)

# for loading the data
import nibabel as nib

# %% [markdown]
# Download & extract MSD Prostate data from https://drive.google.com/drive/folders/1HqEgzS8BV2c7xYNrZdEAnrHk7osJJ--2 (http://medicaldecathlon.com/)

# %% [markdown]
# ---

# %% [markdown]
# Here is a sample code to read the data with the nibabel library:
#
# ```python
# image = nib.load('path_to_file.nii.gz').get_fdata()
# ```
#
# Now write a code to load the first prostate and its segmentation; display their dimensions.

# %% [markdown]
# Note that the image is a 3D volume with 2 channels (for two modlities), and the label is a 3D volume with the same size, but with only 1 channel.
#
# We will only use the first channel of the image (and the only channel of the label).

# %% [markdown]
# Write a code to display a slice of the image and the corresponding label.

# %% [markdown]
# Now, here is a transform that you can use to resize the image and the label to a given size:
#
# ```python
# class Resize3D(object):
#     def __init__(self, size):
#         self.size = size
#
#     def __call__(self, sample):
#         resample = F.interpolate(sample[None,:,:,:].unsqueeze(0), \
#             size=self.size, mode='trilinear', align_corners=False)
#         return resample.squeeze(0)[0,:,:,:]
# ```
#
# Here is how it works:
#
# ```python
# resize10 = Resize3D((10, 10, 10))
# resized_label = resize10(torch.tensor(label))
# ```
#
# Note that `Resize3D` can be used as a transform in a PyTorch dataset.

# %% [markdown]
# Now create a dataset (+ dataloader) with images and labels resized to $(20, 128, 128)$.

# %% [markdown]
# It is not easy to decide on the quality of the segmentation. One way is to compute the Dice score between the predicted segmentation and the ground truth.
# The dice score is defined as the ratio between the intersection of the two segmentations, and the union of the two segmentations.
#
# Define a function that computes the Dice score between two segmentations; test it on `label>0` and `label>1` (labels 1 and 2 correspond to different doctors' segmentations).
