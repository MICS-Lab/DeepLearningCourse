# %% [markdown]
# # TD 6a

# %% [markdown]
# The cells were executed already, so you can just read through the notebook. Be aware that it can be quite long to run the cells on your computer.

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# Rewriting the `print` function (for more info, check [this link](https://www.includehelp.com/python/flush-parameter-in-python-with-print-function.aspx))

# %%
from functools import partial
print = partial(print, flush=True)

# %% [markdown]
# Set random seed for reproducibility

# %%
_ = torch.manual_seed(61998)

# %% [markdown]
# ---
# ### Wide and deep network from last TD

# %% [markdown]
# Define the basic rectangle network.

# %%
class Net(nn.Module):
    def __init__(self, n_layers=1, n_hidden=3):
        super(Net, self).__init__()
        self.fc_in = nn.Linear(1, n_hidden)
        self.fcs = nn.ModuleList([nn.Linear(n_hidden, n_hidden) for i in range(n_layers-1)])
        self.fc_out = nn.Linear(n_hidden, 1)

    def forward(self, x):
        x = F.relu(self.fc_in(x))
        for i in range(len(self.fcs)):
            x = F.relu(self.fcs[i](x))
        x = self.fc_out(x)
        return x

# %% [markdown]
# Define $f$ and $g$

# %%
def f(x):
    return 1-(2*np.abs(x-0.5)).clip(0,1)

def g(x, lvl):
    for i in range(lvl):
        x = f(x)
    return x

# %% [markdown]
# ---
# #### Wide

# %% [markdown]
# One hidden layer only:

# %%
# Create a wide network for lvl=4 and train it
level = 4
n = 2**level + 1
wide = Net(1, n*20)  # a bit more than necessary

# Print the network layers
print(wide)
# Print the number of parameters
print(f'Number of parameters: {sum(p.numel() for p in wide.parameters())}')

x = np.linspace(-0.2, 1.2, 2000)
y = g(x, level)

# Train the network
optimizer = torch.optim.Adam(wide.parameters(), lr=0.02)
for epoch in range(75_000):
    optimizer.zero_grad()
    pred = wide(torch.tensor(x).float().view(-1, 1))
    loss = F.mse_loss(pred, torch.tensor(y).float().view(-1, 1))
    loss.backward()
    optimizer.step()
    if epoch % 1000 == 0:
        print(f'Epoch: {epoch}, loss: {loss.item():.2e}, fc_in W average gradient: {np.mean(wide.fc_in.weight.grad.detach().numpy()):.2e}')

# Plot the result
y = wide(torch.tensor(x).float().view(-1, 1)).detach().numpy()
plt.plot(x, y, label="wide(x)")
plt.legend()
# Out:
# Net(
#   (fc_in): Linear(in_features=1, out_features=340, bias=True)
#   (fcs): ModuleList()
#   (fc_out): Linear(in_features=340, out_features=1, bias=True)
# )
# Number of parameters: 1021
# Epoch: 0, loss: 1.29e-01, fc_in W average gradient: -2.49e-05
# Epoch: 1000, loss: 5.94e-02, fc_in W average gradient: 1.72e-05
# Epoch: 2000, loss: 5.14e-02, fc_in W average gradient: -1.04e-05
# Epoch: 3000, loss: 4.38e-02, fc_in W average gradient: -1.27e-05
# Epoch: 4000, loss: 4.12e-02, fc_in W average gradient: -1.04e-03
# Epoch: 5000, loss: 3.40e-02, fc_in W average gradient: 5.61e-04
# Epoch: 6000, loss: 2.29e-02, fc_in W average gradient: 2.09e-05
# Epoch: 7000, loss: 1.92e-02, fc_in W average gradient: 5.36e-06
# Epoch: 8000, loss: 1.70e-02, fc_in W average gradient: -1.86e-04
# Epoch: 9000, loss: 6.22e-02, fc_in W average gradient: -4.51e-03
# Epoch: 48000, loss: 2.12e-03, fc_in W average gradient: -2.26e-04
# Epoch: 49000, loss: 6.88e-04, fc_in W average gradient: -1.08e-04
# Epoch: 50000, loss: 3.97e-04, fc_in W average gradient: 8.36e-07
# Epoch: 51000, loss: 7.42e-04, fc_in W average gradient: -1.18e-04
# Epoch: 52000, loss: 3.61e-04, fc_in W average gradient: 7.94e-06
# Epoch: 53000, loss: 3.38e-04, fc_in W average gradient: -3.38e-06
# Epoch: 54000, loss: 3.25e-04, fc_in W average gradient: -1.88e-06
# Epoch: 55000, loss: 3.12e-04, fc_in W average gradient: -3.62e-06
# Epoch: 56000, loss: 3.02e-04, fc_in W average gradient: -6.25e-06
# Epoch: 57000, loss: 2.97e-04, fc_in W average gradient: -8.59e-07
# Epoch: 58000, loss: 3.74e-04, fc_in W average gradient: -6.84e-05
# Epoch: 59000, loss: 2.77e-04, fc_in W average gradient: 1.77e-05
# Epoch: 60000, loss: 2.64e-04, fc_in W average gradient: 3.32e-07
# Epoch: 61000, loss: 3.93e-04, fc_in W average gradient: -6.07e-05
# Epoch: 62000, loss: 2.47e-04, fc_in W average gradient: -1.68e-06
# Epoch: 63000, loss: 2.46e-04, fc_in W average gradient: -3.44e-06
# Epoch: 64000, loss: 9.40e-03, fc_in W average gradient: -5.03e-04
# Epoch: 65000, loss: 9.50e-02, fc_in W average gradient: 1.88e-03
# Epoch: 66000, loss: 4.22e-02, fc_in W average gradient: -9.57e-04
# Epoch: 67000, loss: 2.20e-04, fc_in W average gradient: -3.29e-06
# Epoch: 68000, loss: 7.72e-04, fc_in W average gradient: -1.12e-04
# Epoch: 69000, loss: 3.80e-04, fc_in W average gradient: 7.50e-05
# Epoch: 70000, loss: 3.87e-02, fc_in W average gradient: -8.72e-04
# Epoch: 71000, loss: 2.14e-04, fc_in W average gradient: 1.81e-05
# Epoch: 72000, loss: 3.47e-04, fc_in W average gradient: -6.74e-05
# Epoch: 73000, loss: 3.78e-02, fc_in W average gradient: 1.12e-03
# Epoch: 74000, loss: 5.67e-04, fc_in W average gradient: 1.03e-04

# %% [markdown]
# ---
# #### Deep

# %% [markdown]
# Not that many neurons on each layer but many layers:

# %%
# Create a deep network for level 4 and train it
level = 4
deep = Net(level*3, 5)  # a bit more than necessary

# Print the network layers
print(deep)
# Print the number of parameters
print(f'Number of parameters: {sum(p.numel() for p in deep.parameters())}')

x = np.linspace(-0.2, 1.2, 2000)
y = g(x, level)

# Train the network
optimizer = torch.optim.Adam(deep.parameters(), lr=0.02)
for epoch in range(500):  # pas besoin de beaucoup d'epochs pour se rendre compte que le gradient a vanished
    optimizer.zero_grad()
    pred = deep(torch.tensor(x).float().view(-1, 1))
    loss = F.mse_loss(pred, torch.tensor(y).float().view(-1, 1))
    loss.backward()
    optimizer.step()
    if epoch % 100 == 0:
        print(f'Epoch: {epoch}, loss: {loss.item():.2e}, fc_in W average gradient: {np.mean(deep.fc_in.weight.grad.detach().numpy()):.2e}')

# Plot the result
y = deep(torch.tensor(x).float().view(-1, 1)).detach().numpy()
plt.plot(x, y, label="deep(x)")
plt.legend()
# Out:
# Net(
#   (fc_in): Linear(in_features=1, out_features=5, bias=True)
#   (fcs): ModuleList(
#     (0): Linear(in_features=5, out_features=5, bias=True)
#     (1): Linear(in_features=5, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): Linear(in_features=5, out_features=5, bias=True)
#     (4): Linear(in_features=5, out_features=5, bias=True)
#     (5): Linear(in_features=5, out_features=5, bias=True)
#     (6): Linear(in_features=5, out_features=5, bias=True)
#     (7): Linear(in_features=5, out_features=5, bias=True)
#     (8): Linear(in_features=5, out_features=5, bias=True)
#     (9): Linear(in_features=5, out_features=5, bias=True)
#     (10): Linear(in_features=5, out_features=5, bias=True)
#   )
#   (fc_out): Linear(in_features=5, out_features=1, bias=True)
# )
# Number of parameters: 346
# Epoch: 0, loss: 2.09e-01, fc_in W average gradient: 5.27e-08
# Epoch: 100, loss: 1.11e-01, fc_in W average gradient: 0.00e+00
# Epoch: 200, loss: 1.11e-01, fc_in W average gradient: 0.00e+00
# Epoch: 300, loss: 1.11e-01, fc_in W average gradient: 0.00e+00
# Epoch: 400, loss: 1.11e-01, fc_in W average gradient: 0.00e+00

# %% [markdown]
# Look at the gradients! After today's class we can explain what happened last time: *gradient vanishing*.
#
# Let's try and combat the vanishing gradient problem **without removing hidden layers** (as we seen that a deep network is useful because it allows us to have much less parameters to attain the global minimum (theoretically)).

# %% [markdown]
# ---
# Let's try to use a **Leaky ReLU activation function**.

# %%
class LeakyNet(nn.Module):
    def __init__(self, n_layers=1, n_hidden=3):
        super(LeakyNet, self).__init__()
        self.fc_in = nn.Linear(1, n_hidden)
        self.fcs = nn.ModuleList([nn.Linear(n_hidden, n_hidden) for i in range(n_layers-1)])
        self.fc_out = nn.Linear(n_hidden, 1)

    def forward(self, x):
        x = F.leaky_relu(self.fc_in(x), negative_slope=0.1)
        for i in range(len(self.fcs)):
            x = F.leaky_relu(self.fcs[i](x), negative_slope=0.1)
        x = self.fc_out(x)
        return x

# %%
# Create a deep network for level 4 and train it
level = 4
deep = LeakyNet(level*3, 5)

# Print the network layers
print(deep)
# Print the number of parameters
print(f'Number of parameters: {sum(p.numel() for p in deep.parameters())}')

x = np.linspace(-0.2, 1.2, 2000)
y = g(x, level)

# Train the network
optimizer = torch.optim.Adam(deep.parameters(), lr=0.02)
for epoch in range(500):
    optimizer.zero_grad()
    pred = deep(torch.tensor(x).float().view(-1, 1))
    loss = F.mse_loss(pred, torch.tensor(y).float().view(-1, 1))
    loss.backward()
    optimizer.step()
    if epoch % 100 == 0:
        print(f'Epoch: {epoch}, loss: {loss.item():.2e}, fc_in W average gradient: {np.mean(deep.fc_in.weight.grad.detach().numpy()):.2e}')

# Plot the result
y = deep(torch.tensor(x).float().view(-1, 1)).detach().numpy()
plt.plot(x, y, label="deep(x)")
plt.legend()
# Out:
# LeakyNet(
#   (fc_in): Linear(in_features=1, out_features=5, bias=True)
#   (fcs): ModuleList(
#     (0): Linear(in_features=5, out_features=5, bias=True)
#     (1): Linear(in_features=5, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): Linear(in_features=5, out_features=5, bias=True)
#     (4): Linear(in_features=5, out_features=5, bias=True)
#     (5): Linear(in_features=5, out_features=5, bias=True)
#     (6): Linear(in_features=5, out_features=5, bias=True)
#     (7): Linear(in_features=5, out_features=5, bias=True)
#     (8): Linear(in_features=5, out_features=5, bias=True)
#     (9): Linear(in_features=5, out_features=5, bias=True)
#     (10): Linear(in_features=5, out_features=5, bias=True)
#   )
#   (fc_out): Linear(in_features=5, out_features=1, bias=True)
# )
# Number of parameters: 346
# Epoch: 0, loss: 1.28e-01, fc_in W average gradient: -2.34e-08
# Epoch: 100, loss: 1.11e-01, fc_in W average gradient: 3.66e-08
# Epoch: 200, loss: 6.72e-02, fc_in W average gradient: -5.20e-03
# Epoch: 300, loss: 5.20e-02, fc_in W average gradient: 3.16e-03
# Epoch: 400, loss: 4.78e-02, fc_in W average gradient: -3.00e-04

# %% [markdown]
# It's a lot better! It's not the only time we see this, it allows the gradients to not be exactly stuck at 0 (cf. very end of TD 1 in which all the neurons were in the negative part of the ReLU function).

# %% [markdown]
# ---
# Let's try **residual connections** now, because LeakyRelu isn't the only way to combat vanishing gradients.

# %%
class ResidualNet(nn.Module):
    def __init__(self, n_layers=1, n_hidden=3):
        super(ResidualNet, self).__init__()
        self.fc_in = nn.Linear(1, n_hidden)
        self.fcs = nn.ModuleList([nn.Linear(n_hidden, n_hidden) for i in range(n_layers-1)])
        self.fc_out = nn.Linear(n_hidden, 1)

    def forward(self, x):
        res = x
        x = F.relu(self.fc_in(x))
        for i in range(len(self.fcs)):
            x = F.relu(self.fcs[i](x)) + res
        x = self.fc_out(x) + res
        return x

# %%
# Create a deep network for level 4 and train it
level = 4
deep = ResidualNet(level*3, 5)

# Print the network layers
print(deep)
# Print the number of parameters
print(f'Number of parameters: {sum(p.numel() for p in deep.parameters())}')

x = np.linspace(-0.2, 1.2, 2000)
y = g(x, level)

# Train the network
optimizer = torch.optim.Adam(deep.parameters(), lr=0.02)
for epoch in range(500):
    optimizer.zero_grad()
    pred = deep(torch.tensor(x).float().view(-1, 1))
    loss = F.mse_loss(pred, torch.tensor(y).float().view(-1, 1))
    loss.backward()
    optimizer.step()
    if epoch % 100 == 0:
        print(f'Epoch: {epoch}, loss: {loss.item():.2e}, fc_in W average gradient: {np.mean(deep.fc_in.weight.grad.detach().numpy()):.2e}')

# Plot the result
y = deep(torch.tensor(x).float().view(-1, 1)).detach().numpy()
plt.plot(x, y, label="deep(x)")
plt.legend()
# Out:
# ResidualNet(
#   (fc_in): Linear(in_features=1, out_features=5, bias=True)
#   (fcs): ModuleList(
#     (0): Linear(in_features=5, out_features=5, bias=True)
#     (1): Linear(in_features=5, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): Linear(in_features=5, out_features=5, bias=True)
#     (4): Linear(in_features=5, out_features=5, bias=True)
#     (5): Linear(in_features=5, out_features=5, bias=True)
#     (6): Linear(in_features=5, out_features=5, bias=True)
#     (7): Linear(in_features=5, out_features=5, bias=True)
#     (8): Linear(in_features=5, out_features=5, bias=True)
#     (9): Linear(in_features=5, out_features=5, bias=True)
#     (10): Linear(in_features=5, out_features=5, bias=True)
#   )
#   (fc_out): Linear(in_features=5, out_features=1, bias=True)
# )
# Number of parameters: 346
# Epoch: 0, loss: 6.48e-01, fc_in W average gradient: -2.23e-10
# Epoch: 100, loss: 9.03e-02, fc_in W average gradient: 0.00e+00
# Epoch: 200, loss: 7.84e-02, fc_in W average gradient: 0.00e+00
# Epoch: 300, loss: 7.84e-02, fc_in W average gradient: 0.00e+00
# Epoch: 400, loss: 7.84e-02, fc_in W average gradient: 0.00e+00

# %% [markdown]
# It does seem to help, same amount of parameters but cleaner function! You can see that the gradient is stuck at 0 though, it's probably because we don't have enough neurons on each layer so if we're unfortunate and Ax+b is negative or 0 on one entier layer (only 5 neurons per layer here so not that unlikely), the gradient will be stuck at 0...
#
# - Keep in mind we only ran it for 500 epochs whilst we run the wide neural network for 75,000.
# - Keep in mind we are displaying an average of gradients (only on one layer) which doesn't really mean anything except when it's exactly 0 like in the initial case for the `deep` network.

# %% [markdown]
# ---
# Alright, so all good! Everything makes sense, now let's actually train the network and let's combine the two methods previously encountered.
# Keep in mind we haven't changed the number of parameters!

# %%
class ResidualLeakyNet(nn.Module):
    def __init__(self, n_layers=1, n_hidden=3):
        super(ResidualLeakyNet, self).__init__()
        self.fc_in = nn.Linear(1, n_hidden)
        self.fcs = nn.ModuleList([nn.Linear(n_hidden, n_hidden) for i in range(n_layers-1)])
        self.fc_out = nn.Linear(n_hidden, 1)

    def forward(self, x):
        res = x
        x = F.leaky_relu(self.fc_in(x))
        for i in range(len(self.fcs)):
            x = F.leaky_relu(self.fcs[i](x)) + res
        x = self.fc_out(x) + res
        return x

# %%
# Create a deep network for level 4 and train it
level = 4
deep = ResidualLeakyNet(level*3, 5)

# Print the network layers
print(deep)
# Print the number of parameters
print(f'Number of parameters: {sum(p.numel() for p in deep.parameters())}')

x = np.linspace(-0.2, 1.2, 2000)
y = g(x, level)

# Train the network
optimizer = torch.optim.Adam(deep.parameters(), lr=0.02)
for epoch in range(75_000):
    optimizer.zero_grad()
    pred = deep(torch.tensor(x).float().view(-1, 1))
    loss = F.mse_loss(pred, torch.tensor(y).float().view(-1, 1))
    loss.backward()
    optimizer.step()
    if epoch % 1000 == 0:
        print(f'Epoch: {epoch}, loss: {loss.item():.2e}, fc_in W average gradient: {np.mean(deep.fcs[-1].weight.grad.detach().numpy()):.2e}')

# Plot the result
y = deep(torch.tensor(x).float().view(-1, 1)).detach().numpy()
plt.plot(x, y, label="deep(x)")
plt.legend()
# Out:
# ResidualLeakyNet(
#   (fc_in): Linear(in_features=1, out_features=5, bias=True)
#   (fcs): ModuleList(
#     (0): Linear(in_features=5, out_features=5, bias=True)
#     (1): Linear(in_features=5, out_features=5, bias=True)
#     (2): Linear(in_features=5, out_features=5, bias=True)
#     (3): Linear(in_features=5, out_features=5, bias=True)
#     (4): Linear(in_features=5, out_features=5, bias=True)
#     (5): Linear(in_features=5, out_features=5, bias=True)
#     (6): Linear(in_features=5, out_features=5, bias=True)
#     (7): Linear(in_features=5, out_features=5, bias=True)
#     (8): Linear(in_features=5, out_features=5, bias=True)
#     (9): Linear(in_features=5, out_features=5, bias=True)
#     (10): Linear(in_features=5, out_features=5, bias=True)
#   )
#   (fc_out): Linear(in_features=5, out_features=1, bias=True)
# )
# Number of parameters: 346
# Epoch: 0, loss: 1.03e-01, fc_in W average gradient: 1.22e-03
# Note: it adds two parameters* for each batch normalization layer: among other things the mean and variance of the batch, which are used to normalize the activations. These parameters are typically learned during the training process, just like the weights of a linear layer. But the benefits of batch normalization are a lot more than what you'd get by adding a few neurons to your network. As explained in Lecture 3, the reasons why batch normalization work are not fully understood yet.
#
# \* unless you set affine=False in the batch normalization layer, which is not recommended.

# %%
class BatchNormalizationResidualLeakyNet(nn.Module):
    def __init__(self, n_layers=1, n_hidden=3):
        super(BatchNormalizationResidualLeakyNet, self).__init__()
        self.fc_in = nn.Linear(1, n_hidden)
        self.batch_norm_in = nn.BatchNorm1d(n_hidden)
        self.fcs = nn.ModuleList([nn.Sequential(nn.Linear(n_hidden, n_hidden), nn.BatchNorm1d(n_hidden)) for i in range(n_layers-1)])
        self.fc_out = nn.Linear(n_hidden, 1)  # no batch normalization on the last layer

    def forward(self, x):
        res = x
        x = F.leaky_relu(self.batch_norm_in(self.fc_in(x)), negative_slope=0.1)
        for i in range(len(self.fcs)):
            x = F.leaky_relu(self.fcs[i][1](self.fcs[i][0](x)), negative_slope=0.1) + res
        x = self.fc_out(x) + res
        return x

# %%
# Print the number of parameters of the previous network deep
print(f'Number of parameters of the previous network deep: {sum(p.numel() for p in deep.parameters())}')

# Create a deep network for level 4
level = 4
deep = BatchNormalizationResidualLeakyNet(level*3, 5)
# Print the number of parameters of the new network deep
print(f'Number of parameters of the new network deep: {sum(p.numel() for p in deep.parameters())}')
print(deep)
# Out:
# Number of parameters of the previous network deep: 346
# Number of parameters of the new network deep: 466
# BatchNormalizationResidualLeakyNet(
#   (fc_in): Linear(in_features=1, out_features=5, bias=True)
#   (batch_norm_in): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fcs): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=5, out_features=5, bias=True)
#       (1): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=5, out_features=5, bias=True)
#       (1): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Sequential(
#       (0): Linear(in_features=5, out_features=5, bias=True)
#       (1): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Sequential(
#       (0): Linear(in_features=5, out_features=5, bias=True)
#       (1): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): Sequential(
#       (0): Linear(in_features=5, out_features=5, bias=True)
#       (1): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): Sequential(
#       (0): Linear(in_features=5, out_features=5, bias=True)
#       (1): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (6): Sequential(
#       (0): Linear(in_features=5, out_features=5, bias=True)
#       (1): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (7): Sequential(
#       (0): Linear(in_features=5, out_features=5, bias=True)
#       (1): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (8): Sequential(
#       (0): Linear(in_features=5, out_features=5, bias=True)
#       (1): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (9): Sequential(
#       (0): Linear(in_features=5, out_features=5, bias=True)
#       (1): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (10): Sequential(
#       (0): Linear(in_features=5, out_features=5, bias=True)
#       (1): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fc_out): Linear(in_features=5, out_features=1, bias=True)
# )

# %% [markdown]
# How many new parameters? 120 new parameters, because we have 12 layers with 5 neurons (i.e. $12*5*2$).

# %%
# Let's train our new network

x = np.linspace(-0.2, 1.2, 2000)
y = g(x, level)

# Train the network
optimizer = torch.optim.Adam(deep.parameters(), lr=0.02)
for epoch in range(75_000):
    optimizer.zero_grad()
    pred = deep(torch.tensor(x).float().view(-1, 1))
    loss = F.mse_loss(pred, torch.tensor(y).float().view(-1, 1))
    loss.backward()
    optimizer.step()
    if epoch % 1000 == 0:
        print(f'Epoch: {epoch}, loss: {loss.item():.2e}, fc_in W average gradient: {np.mean(deep.fcs[-1][-1].weight.grad.detach().numpy()):.2e}')

# Plot the result
y = deep(torch.tensor(x).float().view(-1, 1)).detach().numpy()
plt.plot(x, y, label="deep(x)")
plt.legend()
# Out:
# Epoch: 0, loss: 5.55e-01, fc_in W average gradient: 8.72e-02
# Epoch: 1000, loss: 7.75e-05, fc_in W average gradient: 9.78e-05
# Epoch: 2000, loss: 3.16e-04, fc_in W average gradient: -1.41e-04
# Epoch: 3000, loss: 2.55e-04, fc_in W average gradient: -3.68e-04
# Epoch: 4000, loss: 1.27e-04, fc_in W average gradient: 1.20e-05
# Epoch: 5000, loss: 4.97e-04, fc_in W average gradient: -2.96e-04
# Epoch: 44000, loss: 8.75e-06, fc_in W average gradient: -7.11e-05
# Epoch: 45000, loss: 1.06e-04, fc_in W average gradient: 2.13e-04
# Epoch: 46000, loss: 2.58e-04, fc_in W average gradient: 2.82e-04
# Epoch: 47000, loss: 1.47e-05, fc_in W average gradient: 2.84e-05
# Epoch: 48000, loss: 2.29e-05, fc_in W average gradient: 1.21e-04
# Epoch: 49000, loss: 4.00e-05, fc_in W average gradient: -5.11e-05
# Epoch: 50000, loss: 2.38e-05, fc_in W average gradient: 1.13e-04
# Epoch: 51000, loss: 2.12e-05, fc_in W average gradient: -1.63e-04
# Epoch: 52000, loss: 3.70e-05, fc_in W average gradient: 1.07e-04
# Epoch: 53000, loss: 1.19e-04, fc_in W average gradient: -2.09e-04
# Epoch: 54000, loss: 3.07e-05, fc_in W average gradient: -1.63e-04
# Epoch: 55000, loss: 7.65e-05, fc_in W average gradient: 1.43e-04
# Epoch: 56000, loss: 5.38e-05, fc_in W average gradient: -3.18e-04
# Epoch: 57000, loss: 8.92e-05, fc_in W average gradient: -1.45e-04
# Epoch: 58000, loss: 4.95e-06, fc_in W average gradient: 2.41e-05
# Epoch: 59000, loss: 7.96e-05, fc_in W average gradient: -1.86e-04
# Epoch: 60000, loss: 7.10e-05, fc_in W average gradient: 7.19e-05
# Epoch: 61000, loss: 2.88e-05, fc_in W average gradient: -2.13e-04
# Epoch: 62000, loss: 2.55e-05, fc_in W average gradient: -3.96e-05
# Epoch: 63000, loss: 5.09e-05, fc_in W average gradient: 1.89e-04
# Epoch: 64000, loss: 4.02e-05, fc_in W average gradient: 1.14e-04
# Epoch: 65000, loss: 2.38e-05, fc_in W average gradient: -3.11e-05
# Epoch: 66000, loss: 1.36e-04, fc_in W average gradient: -1.23e-06
# Epoch: 67000, loss: 3.99e-05, fc_in W average gradient: -1.13e-04
# Epoch: 68000, loss: 5.08e-05, fc_in W average gradient: -1.35e-04
# Epoch: 69000, loss: 4.41e-05, fc_in W average gradient: 1.75e-04
# Epoch: 70000, loss: 1.17e-04, fc_in W average gradient: -8.52e-05
# Epoch: 71000, loss: 7.11e-05, fc_in W average gradient: -8.90e-05
# Epoch: 72000, loss: 9.90e-06, fc_in W average gradient: 7.37e-05
# Epoch: 73000, loss: 4.07e-05, fc_in W average gradient: -5.78e-05
# Epoch: 74000, loss: 1.95e-05, fc_in W average gradient: 5.29e-05

# %% [markdown]
# Obviously it all comes back to choosing good hyperparameters (using residual connections or not, batch normalization or not are hyperparameters in itself), but knowing what happens can help understanding how the hyperparameters should be changed. It's impossible to always get it right (so we test everything on big compuetrs) but some rules are obvious ... e.g., if you've got a vanishing gradient problem, please do not add hidden layers ... That's what will differentiate good deep learning engineers from you know ... less experienced ones.
#
# Here the obvious solution would've been to have a network with less hidden layers, and more neurons per layer without increasing the number of parameters to the huge number we need in the wide network. The deep network was obviously 'too deep' and not 'wide enough' for the problem at hand.
